# %% [markdown]
# bertopic

# %%
import re
import unicodedata
import pandas as pd
import os
import openai
import time

from bertopic import BERTopic
from hdbscan import HDBSCAN
from bertopic.representation import OpenAI

# %% [markdown]
# ## Data Preprocessing

# %%
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()

    # Normalize unicode characters
    text = unicodedata.normalize("NFKC", text)

    # Remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()

    # Remove special characters (optional)
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)

    return text

def load_and_process(file):
  df = pd.read_csv(file, names=['id', 'entity', 'label', 'text'])
  df = df.drop_duplicates().dropna()
  df['text_processed'] = df['text'].apply(preprocess_text)

  return df

df = load_and_process("~/sentiment_analysis/archive/twitter_training.csv")
df.drop_duplicates(subset='id', keep='first', inplace=True)
df = df[df['label']=='Negative']
grouped_df = df.groupby('entity')
documents_grouped = {}
for entity, group in grouped_df: 
    documents_grouped[entity] = group['text_processed'].tolist()

# %% [markdown]
# ## Topic Modeling

# %%
topic_models  = {}
for entity, documents in documents_grouped.items():
    '''
    client = openai.OpenAI()
    representation_model = OpenAI(
        client, 
        model="gpt-4o-mini", 
        chat=True, 
        nr_docs=4, 
        delay_in_seconds=30, 
        exponential_backoff=True
    )
    '''
    hdbscan_model = HDBSCAN(min_cluster_size=2)
    topic_model = BERTopic(
        #representation_model=representation_model, 
        hdbscan_model=hdbscan_model, 
        nr_topics=5
    )
    topic_model.fit(documents)
    topic_models[entity] = topic_model

# %% [markdown]
# ## Topic Summary with Prompts Engineering

# %%
prompts = {}
for entity, topic_model in topic_models.items(): 
    representative_docs = topic_model.get_representative_docs()
    system_msg = '''
Your goal is to create concise, human-readable summaries of topics based on their representative documents, for the entity: {entity}. 
'''.format(
        entity=entity, 
    )
    user_msg = '''
Input Details: 
•	The input is a dictionary consists of topic number and representative documents
•	The representative documents are an array of strings 

Output Requirements: 
    1.	For each topic, provide:
        ◦	A title of 3-5 words summarizing the topic.
        ◦	A sentence explaining the topic based on its top words.
        ◦	Organize them into dictionary 
    2.  Organize the topic into array 
    3.  Output result of list as json 
Input: 
{docs}
'''.format(
        docs=str(representative_docs),
    )
    prompts[entity] = [system_msg, user_msg]

# %%
client = openai.OpenAI()
def get_model_response(messages, 
                       model = 'gpt-4o-mini', 
                       temperature = 0, 
                       max_tokens = 1000):
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature, 
        max_tokens=max_tokens, 
    )

    return response.choices[0].message.content

for entity, prompt in prompts.items(): 
    messages = [
        {'role': 'system', 'content': prompt[0]},
        {'role': 'user', 'content': prompt[1]},
    ]
    print(entity)
    summary = get_model_response(messages)
    print(summary)
    time.sleep(30)
# Out:
# Amazon
# ```json
# {
#     "topics": [
#         {
#             "title": "Customer Service Issues",
#             "summary": "Customers express frustration over delivery failures and service problems with Amazon."
#         },
#         {
#             "title": "Order Cancellations and Frustrations",
#             "summary": "Users report dissatisfaction with order cancellations and difficulties in finding products on Amazon."
#         },
#         {
#             "title": "Mask Shortages During Pandemic",
#             "summary": "Consumers struggle to find face masks on Amazon, facing delays and price gouging."
#         },
#         {
#             "title": "Criticism of Corporate Practices",
#             "summary": "Critics highlight the ethical concerns surrounding Amazon's wealth and treatment of workers."
#         }
#     ]
# }
# ```
# ApexLegends
# ```json
# {
#     "topics": [
#         {
#             "title": "Game Issues and Complaints",
#             "summary": "Players express frustration over game bugs and server issues in Apex Legends."
#         },
#         {
#             "title": "Technical Problems and Feedback",
#             "summary": "Users report technical difficulties, including freezing and disconnections, highlighting a lack of responsiveness from developers."
#         },
#         {
#             "title": "Casual Reactions and Memes",
#             "summary": "Players share light-hearted or humorous reactions to in-game situations."
#         },
#         {
#             "title": "Community Engagement and Comparisons",
#             "summary": "Discussions on community engagement and comparisons with other successful games."
#         }
#     ]
# }
# ```
# AssassinsCreed
# ```json
# {
#     "topics": [
#         {
#             "title": "Frustration with Game Mechanics",
#             "description": "This topic reflects players' frustrations with game mechanics and character interactions in the Assassins Creed series."
#         },
#         {
#             "title": "Character Development Concerns",
#             "description": "This topic discusses the perceived lack of character depth and the need for change in storytelling within the Assassins Creed franchise."
#         }
#     ]
# }
# ```
# Battlefield
# ```json
# {
#     "topics": [
#         {
#             "title": "Battlefield V Bug Reports",
#             "summary": "Users are reporting bugs and issues related to Battlefield V, particularly concerning the Globetrotter feature and account access."
#         },
#         {
#             "title": "Account Issues in Battlefield",
#             "summary": "Players are experiencing difficulties logging into Battlefield V and other EA games due to account validation problems."
#         },
#         {
#             "title": "Game Updates and Feedback",
#             "summary": "There are discussions about potential changes to game modes in Battlefield, reflecting on player feedback and past game experiences."
#         }
#     ]
# }
# ```
# Borderlands
# ```json
# {
#     "topics": [
#         {
#             "title": "Borderlands Game Frustrations",
#             "summary": "Players express dissatisfaction with various issues in Borderlands games, including loot mechanics and game-breaking bugs."
#         },
#         {
#             "title": "Technical Issues in Borderlands",
#             "summary": "Users report significant technical problems such as lag, crashes, and audio issues affecting gameplay on different consoles."
#         },
#         {
#             "title": "Game Design Concerns",
#             "summary": "Players voice concerns over game design choices, including loot payouts and gameplay mechanics that feel unbalanced or frustrating."
#         },
#         {
#             "title": "Loot Drop Rate Complaints",
#             "summary": "Gamers are unhappy with the perceived decline in loot drop rates and the impact of game updates on their experience."
#         }
#     ]
# }
# ```
# CS-GO
# ```json
# {
#     "topics": [
#         {
#             "title": "Game Frustrations",
#             "summary": "Players express extreme dissatisfaction with the game's mechanics and overall experience."
#         },
#         {
#             "title": "Cheating Concerns",
#             "summary": "The community is worried about rampant cheating affecting gameplay and calls for solutions from developers."
#         }
#     ]
# }
# ```
# CallOfDuty
# ```json
# [
#     {
#         "title": "Gaming Community Reactions",
#         "description": "This topic reflects the intense emotions and reactions of gamers, often expressing frustration and humor regarding their experiences."
#     },
#     {
#         "title": "Call of Duty Issues",
#         "description": "This topic addresses technical problems and frustrations players face with Call of Duty, particularly with updates and game performance."
#     }
# ]
# ```
# CallOfDutyBlackopsColdWar
# ```json
# {
#     "topics": [
#         {
#             "title": "Community Concerns and Feedback",
#             "summary": "Players express frustration over issues like racism, game mechanics, and lack of prestige modes in Black Ops Cold War."
#         },
#         {
#             "title": "Gameplay Mechanics Critique",
#             "summary": "Critics highlight that Black Ops Cold War feels outdated compared to Modern Warfare, with slow gunplay and weak sound design."
#         },
#         {
#             "title": "Difficulty and Challenge",
#             "summary": "Players anticipate high difficulty levels in the game, expressing concerns about its overall quality."
#         },
#         {
#             "title": "Platform Exclusivity Issues",
#             "summary": "Players are frustrated with the storage requirements and additional costs associated with playing on different consoles."
#         },
#         {
#             "title": "Legacy Comparisons",
#             "summary": "Fans compare Black Ops Cold War to previous titles, noting that some features, like mastery camos, are disappointing."
#         }
#     ]
# }
# ```
# Cyberpunk2077
# ```json
# [
#     {
#         "title": "Disappointment in Delays",
#         "summary": "This topic reflects the frustration and disappointment expressed by individuals regarding delays in projects, particularly in the context of gaming."
#     },
#     {
#         "title": "Realism in Game Characters",
#         "summary": "This topic discusses the mixed feelings about using real-life models for video game characters, specifically in relation to Cyberpunk 2077 and its protagonist."
#     }
# ]
# ```
# Dota2
# ```json
# {
#     "topics": [
#         {
#             "title": "Community Frustrations",
#             "summary": "The Dota 2 community expresses frustration over perceived neglect by Valve and dissatisfaction with game features."
#         },
#         {
#             "title": "Confusion and Discontent",
#             "summary": "Users are expressing confusion and discontent, often using the term 'wtf' to convey their feelings."
#         },
#         {
#             "title": "Toxic Gaming Environment",
#             "summary": "The topic highlights issues of toxicity within the Dota 2 community, particularly in Southeast Asian servers."
#         },
#         {
#             "title": "Feeling of Wasted Time",
#             "summary": "Players reflect on their experiences with Dota 2, feeling that they have wasted time and money on the game."
#         }
#     ]
# }
# ```
# FIFA
# ```json
# {
#     "topics": [
#         {
#             "title": "FIFA Community Frustrations",
#             "summary": "Players express dissatisfaction with FIFA's gameplay balance and community behavior."
#         },
#         {
#             "title": "Discontent with FIFA Games",
#             "summary": "Gamers criticize FIFA for perceived lack of improvement and frustrating experiences."
#         },
#         {
#             "title": "Negative Gaming Experiences",
#             "summary": "Players share their grievances about poor game mechanics and unfair situations."
#         },
#         {
#             "title": "FIFA Soundtrack Criticism",
#             "summary": "Fans lament the quality of FIFA soundtracks and suggest personal alternatives."
#         }
#     ]
# }
# ```
# Facebook
# ```json
# {
#   "topics": [
#     {
#       "title": "Tech Issues and Delays",
#       "summary": "Technical problems postponed a significant hearing involving major tech companies, including Facebook."
#     },
#     {
#       "title": "Facebook and Privacy Concerns",
#       "summary": "Users express frustration over privacy issues and the impact of social media on personal information."
#     },
#     {
#       "title": "Criticism of Facebook's Leadership",
#       "summary": "Facebook faces backlash and accusations of cowardice and bias from users and stakeholders."
#     },
#     {
#       "title": "User Reactions and Feedback",
#       "summary": "Users share their strong opinions and reactions regarding various aspects of Facebook."
#     },
#     {
#       "title": "Concerns Over Human Life",
#       "summary": "Discussions highlight a perceived lack of regard for human life in the context of social media."
#     }
#   ]
# }
# ```
# Fortnite
# ```json
# {
#     "topics": [
#         {
#             "title": "Frustration with Fortnite",
#             "summary": "Players express extreme dissatisfaction with Fortnite, feeling that the game has become unenjoyable and frustrating."
#         },
#         {
#             "title": "Console Player Issues",
#             "summary": "Console players are voicing concerns about gameplay delays and changes that negatively impact their experience."
#         },
#         {
#             "title": "Mixed Reactions",
#             "summary": "Players share a range of reactions, from indifference to frustration, regarding various aspects of the game."
#         },
#         {
#             "title": "Considering Quitting",
#             "summary": "Some players are contemplating quitting Fortnite due to ongoing frustrations and negative experiences."
#         },
#         {
#             "title": "Bullying and Annoyance",
#             "summary": "Players feel bullied or annoyed by the game's mechanics and community interactions."
#         }
#     ]
# }
# ```
# Google
# ```json
# {
#   "topics": [
#     {
#       "title": "Google's Reputation Issues",
#       "summary": "This topic discusses various criticisms and negative perceptions surrounding Google, including claims of misinformation and user dissatisfaction."
#     },
#     {
#       "title": "Google Support Complaints",
#       "summary": "Users express frustration with Google support services, highlighting issues with product functionality and customer service experiences."
#     },
#     {
#       "title": "Censorship and Content Control",
#       "summary": "This topic revolves around concerns regarding censorship on platforms like Google, with users feeling their content is being unfairly moderated."
#     },
#     {
#       "title": "Product Performance Concerns",
#       "summary": "Users compare the performance of Google products, particularly in relation to competitors, expressing disappointment in battery life and functionality."
#     }
#   ]
# }
# ```
# GrandTheftAuto(GTA)
# ```json
# {
#     "topics": [
#         {
#             "title": "GTA V Issues and Frustrations",
#             "summary": "Players express dissatisfaction with technical issues and support from Rockstar Games regarding GTA V."
#         },
#         {
#             "title": "GTA Community Sentiments",
#             "summary": "Long-time fans of GTA voice their concerns about the game's development and the anticipation for GTA 6."
#         },
#         {
#             "title": "Technical Problems in GTA",
#             "summary": "Users report persistent technical problems and seek assistance for installation and loading issues in GTA."
#         },
#         {
#             "title": "GTA's Depiction of Crime",
#             "summary": "Discussions arise around the portrayal of crime in GTA, reflecting on its impact and character experiences."
#         }
#     ]
# }
# ```
# Hearthstone
# ```json
# {
#     "topics": [
#         {
#             "title": "Matchmaking and Server Issues",
#             "summary": "Players are experiencing significant problems with matchmaking and server stability in Hearthstone."
#         },
#         {
#             "title": "Mobile App Problems",
#             "summary": "Users are facing difficulties accessing Hearthstone on iOS, including update issues and app crashes."
#         },
#         {
#             "title": "Arena Gameplay Frustrations",
#             "summary": "Players express dissatisfaction with the current state of the Arena mode, citing balance issues and a lack of variety."
#         },
#         {
#             "title": "Game Mechanics Complaints",
#             "summary": "Community members are frustrated with certain gameplay mechanics, particularly regarding turn timing and card management."
#         }
#     ]
# }
# ```
# HomeDepot
# ```json
# {
#     "topics": [
#         {
#             "title": "Customer Experience Issues",
#             "summary": "Customers express frustration over long wait times, lost items, and damaged products from Home Depot."
#         },
#         {
#             "title": "Boycotts and Political Sentiments",
#             "summary": "There is a growing sentiment among customers to boycott Home Depot due to political affiliations and support."
#         },
#         {
#             "title": "Lawsuits and Financial Concerns",
#             "summary": "Home Depot faces legal challenges regarding its 401k plan and allegations of poor fund management."
#         },
#         {
#             "title": "Service and Installation Complaints",
#             "summary": "Customers report dissatisfaction with Home Depot's installation services, leading to significant home issues."
#         }
#     ]
# }
# ```
# LeagueOfLegends
# ```json
# {
#     "topics": [
#         {
#             "title": "Toxicity in League of Legends",
#             "summary": "Players express frustration over toxic behavior and account selling in League of Legends."
#         },
#         {
#             "title": "Discontent with Game Changes",
#             "summary": "Many players are unhappy with recent game updates, particularly the introduction of new characters like Seraphine."
#         },
#         {
#             "title": "Game Mechanics and Status Effects",
#             "summary": "Discussion around game mechanics, including status effects and their impact on gameplay."
#         },
#         {
#             "title": "General Frustration with the Game",
#             "summary": "Players share their growing dislike for League of Legends and contemplate quitting."
#         }
#     ]
# }
# ```
# MaddenNFL
# ```json
# {
#     "-1": {
#         "title": "Frustrations with Madden NFL",
#         "summary": "Players express dissatisfaction with Madden NFL due to perceived lack of skill gap, server issues, and repetitive gameplay."
#     },
#     "0": {
#         "title": "Gameplay Issues and Bugs",
#         "summary": "Gamers criticize Madden NFL for persistent bugs and unplayable game modes, questioning the value of annual purchases."
#     },
#     "1": {
#         "title": "Content Updates and Player Cards",
#         "summary": "Fans are frustrated with the lack of updates for player cards in Ultimate Team, particularly for notable players like Jadeveon Clowney."
#     },
#     "2": {
#         "title": "Negative Reception of Graphics",
#         "summary": "Players mock the graphics and overall presentation of Madden NFL, calling it embarrassing and subpar."
#     },
#     "3": {
#         "title": "Player Disrespect in Ratings",
#         "summary": "Fans highlight perceived disrespect towards certain players in Madden NFL ratings and updates."
#     }
# }
# ```
# Microsoft
# ```json
# {
#     "topics": [
#         {
#             "title": "User Reactions to Microsoft",
#             "summary": "This topic reflects mixed user sentiments regarding Microsoft's recent decisions and product support."
#         },
#         {
#             "title": "End of Windows 7 Support",
#             "summary": "This topic discusses Microsoft's cessation of support for Windows 7, highlighting security vulnerabilities for users."
#         }
#     ]
# }
# ```
# NBA2K
# ```json
# {
#     "topics": [
#         {
#             "title": "Community Frustrations",
#             "summary": "Players express dissatisfaction with NBA2K's gameplay mechanics and community feedback."
#         },
#         {
#             "title": "Shooting Mechanics Issues",
#             "summary": "Users are struggling with the new shooting mechanics and demand changes to improve gameplay."
#         },
#         {
#             "title": "General Discontent",
#             "summary": "Players convey their overall dislike and frustration with the game."
#         },
#         {
#             "title": "Game Experience Complaints",
#             "summary": "Users share negative experiences and frustrations with game features and updates."
#         }
#     ]
# }
# ```
# Nvidia
# ```json
# {
#     "0": {
#         "title": "Gaming Community Reactions",
#         "summary": "The topic reflects strong reactions from the gaming community regarding Nvidia's products."
#     },
#     "1": {
#         "title": "Nvidia Card Launch Confusion",
#         "summary": "This topic discusses the confusion and disappointment surrounding the launch of new Nvidia graphics cards."
#     }
# }
# ```
# Overwatch
# ```json
# {
#     "topics": [
#         {
#             "title": "Overwatch Community Frustrations",
#             "summary": "Players express disappointment with Overwatch's focus on esports and balance issues."
#         },
#         {
#             "title": "Declining Interest in Overwatch",
#             "summary": "Fans share their waning interest in Overwatch and concerns over game development and content."
#         },
#         {
#             "title": "Character Design Discussions",
#             "summary": "Players engage in humorous and critical discussions about character aesthetics and design."
#         },
#         {
#             "title": "Character Balance Controversies",
#             "summary": "The community reacts to character nerfs and bans, showcasing strong opinions on balance changes."
#         },
#         {
#             "title": "Game Performance Complaints",
#             "summary": "Players voice frustrations about game performance and character effectiveness in matches."
#         }
#     ]
# }
# ```
# PlayStation5(PS5)
# ```json
# {
#     "topics": [
#         {
#             "title": "PS5 Game Exclusives",
#             "summary": "The PS5 is favored for its exclusive games, which many believe surpass those available on Xbox."
#         },
#         {
#             "title": "PS5 Design Concerns",
#             "summary": "There are mixed feelings about the PS5's design, with some users expressing dissatisfaction with its size."
#         },
#         {
#             "title": "Console Wars Commentary",
#             "summary": "Discussions around console wars often lead to humorous and critical remarks about the rivalry between PlayStation and Xbox."
#         }
#     ]
# }
# ```
# PlayerUnknownsBattlegrounds(PUBG)
# ```json
# {
#     "topics": [
#         {
#             "title": "PUBG Mobile Installation Issues",
#             "summary": "Users are experiencing difficulties installing PUBG Mobile due to storage and access problems."
#         },
#         {
#             "title": "Account Hacking Concerns",
#             "summary": "Players are reporting account hacks and requesting assistance in recovering their compromised PUBG accounts."
#         },
#         {
#             "title": "Banning PUBG Discussions",
#             "summary": "There are ongoing discussions about the potential banning of PUBG, focusing on its impact on students and national interests."
#         },
#         {
#             "title": "Support for PUBG Ban",
#             "summary": "Some players express support for the decision to ban PUBG, viewing it as a positive step for society."
#         }
#     ]
# }
# ```
# RedDeadRedemption(RDR)
# ```json
# {
#     "-1": {
#         "title": "Frustrations with Gameplay",
#         "summary": "Players express frustration over character deaths and gameplay mechanics in Red Dead Redemption 2."
#     },
#     "0": {
#         "title": "Technical Issues and Bugs",
#         "summary": "Users report numerous technical problems and bugs in Red Dead Redemption 2, particularly in online play."
#     },
#     "1": {
#         "title": "Character and Humor",
#         "summary": "Players share humorous and memorable moments related to character interactions in Red Dead Redemption 2."
#     },
#     "2": {
#         "title": "Emotional Impact of Story",
#         "summary": "The storyline of Red Dead Redemption 2 evokes strong emotional responses, leaving players deeply affected."
#     },
#     "3": {
#         "title": "Mixed Opinions on Gameplay",
#         "summary": "While some players appreciate the open world of Red Dead Redemption, others find it boring compared to other games."
#     }
# }
# ```
# TomClancysGhostRecon
# ```json
# {
#     "topics": [
#         {
#             "title": "Game Crashes and Bugs",
#             "summary": "Players are experiencing frequent crashes and bugs in Ghost Recon Breakpoint, leading to frustration and requests for fixes."
#         },
#         {
#             "title": "Gameplay Issues and Feedback",
#             "summary": "Users are reporting various gameplay issues, including overpowered enemies and visibility problems, seeking improvements and adjustments."
#         },
#         {
#             "title": "Technical Glitches",
#             "summary": "There are ongoing technical glitches affecting gameplay, such as menu cursor issues and character model problems, prompting calls for updates."
#         },
#         {
#             "title": "Performance Problems",
#             "summary": "Players are facing performance issues, including hardware limitations and driving difficulties, impacting their gaming experience."
#         }
#     ]
# }
# ```
# TomClancysRainbowSix
# ```json
# {
#     "topics": [
#         {
#             "title": "Server Issues and Disconnects",
#             "summary": "Players are experiencing frequent server disconnections and matchmaking problems in Rainbow Six.",
#             "topic_number": -1
#         },
#         {
#             "title": "Matchmaking Problems",
#             "summary": "Players are frustrated with the matchmaking system that often pairs them with random teammates instead of their friends.",
#             "topic_number": 0
#         },
#         {
#             "title": "Operator Selection Issues",
#             "summary": "Players are facing issues with operator selection during matches, leading to unfavorable gameplay experiences.",
#             "topic_number": 1
#         },
#         {
#             "title": "Cheating and Glitches",
#             "summary": "There are ongoing concerns about cheating and game glitches affecting player experience in Rainbow Six.",
#             "topic_number": 2
#         },
#         {
#             "title": "General Frustration",
#             "summary": "Players express general frustration and disappointment with their gaming experience.",
#             "topic_number": 3
#         }
#     ]
# }
# ```
# Verizon
# ```json
# {
#   "topics": [
#     {
#       "title": "Customer Service Complaints",
#       "summary": "Customers express frustration with Verizon's lack of curbside assistance and account issues."
#     },
#     {
#       "title": "Internet Speed Issues",
#       "summary": "Users report discrepancies between their paid internet speeds and actual performance."
#     },
#     {
#       "title": "Commercial Criticism",
#       "summary": "Critiques of Verizon's advertising featuring unkempt individuals and perceived insincerity."
#     },
#     {
#       "title": "General Discontent",
#       "summary": "Expressions of dissatisfaction and confusion regarding Verizon's services."
#     }
#   ]
# }
# ```
# WorldOfCraft
# ```json
# {
#     "topics": [
#         {
#             "title": "Frustration with Gameplay",
#             "summary": "Players express their dissatisfaction with the current state of gameplay in World of Warcraft, citing reasons for quitting and frustrations with game mechanics."
#         },
#         {
#             "title": "Blizzard's Poor Reputation",
#             "summary": "Criticism of Blizzard's handling of game releases, particularly Warcraft 3 Reforged, highlights a decline in the company's credibility and player trust."
#         },
#         {
#             "title": "Mixed Reactions to Updates",
#             "summary": "Players share varied opinions on recent updates and changes, with some expressing excitement while others voice their discontent."
#         },
#         {
#             "title": "Technical Issues in Game",
#             "summary": "Concerns are raised about technical problems in World of Warcraft, including loading issues and gameplay mechanics that frustrate players."
#         }
#     ]
# }
# ```
# Xbox(Xseries)
# ```json
# [
#     {
#         "title": "Frustration and Humor",
#         "summary": "This topic reflects a mix of frustration and humor in online interactions, showcasing the playful yet aggressive banter among users."
#     },
#     {
#         "title": "Xbox Series X Controversies",
#         "summary": "This topic discusses the controversies surrounding the Xbox Series X, including comparisons to PCs, issues with scalpers, and the absence of year-one exclusives."
#     }
# ]
# ```
# johnson&johnson
# ```json
# {
#     "topics": [
#         {
#             "title": "Johnson & Johnson Controversies",
#             "summary": "This topic discusses the controversies surrounding Johnson & Johnson, particularly related to their talc-based baby powder and its alleged links to cancer."
#         },
#         {
#             "title": "Vaccine Trust Issues",
#             "summary": "Concerns are raised about trusting Johnson & Johnson with a COVID-19 vaccine due to their past issues with product safety."
#         },
#         {
#             "title": "Corporate Responsibility and Racism",
#             "summary": "This topic highlights criticisms of Johnson & Johnson's corporate practices, particularly regarding their support of controversial figures and issues of racial equity."
#         },
#         {
#             "title": "Safety of Baby Powder Products",
#             "summary": "Discussions focus on the safety of Johnson & Johnson's baby powder, with many questioning its long-term health effects."
#         }
#     ]
# }
# ```

# %%
for entity, model in topic_models.items(): 
    print(entity) 
    print(model.get_topic_info())
    print(str(model.get_representative_docs()))
    print('----------------------------------------')
# 1      0     13                       0_eahelp_play_my_cant
# 2      1     65                    1_battlefield_the_to_and
#
#                                       Representation  \
# 0  [regarding, niklasastrand, hoping, reported, a...
# 1  [eahelp, play, my, cant, battlefield, and, to,...
# 2  [battlefield, the, to, and, of, it, is, in, on...
#
#                                  Representative_Docs
# 0  [niklasastrand hey i was hoping you can help i...
# 1  [eahelp hello im having a problem trying to pl...
# 2  [looks like dice may be working on rolling bac...
# {-1: ['niklasastrand hey i was hoping you can help i reported a bug regarding the globetrotter on battlefield v but no update has been given about a fix or patch '], 0: ['eahelp hello im having a problem trying to play battlefield v on my xbox one s it says that my account is invalid could you give me some assistance', 'eahelp i havent been able to log on to battlefield v on xbox one and a friend encountered the same issue we just cant go in and data wont sync however bf1 nhl 20 and all other games i have appear to be fine though why is that', 'eahelp why is my ea account telling me its invalid why wont you let me play star wars battlefront 2 or battlefield v why havent you resolved this issue yet why do you not want me play ea games'], 1: ['looks like dice may be working on rolling back grand operations to the bf1 operations setup w battalions and cinematic intros  at this stage though is it really worth it  fine if youre going to do this 3 months after launch due to feedback but 17 months after launch', 'with ps4 there was a relatively global launch so got an official uk machine very little worth playing in the first year  battlefield 4 aside  but the price made it a better bet than the xbox one at launch fave games god of war last of us 2 uncharted 4 destiny', 'eadice im trying to get the f2000 in battlefield 4 but its impossible its a weapon that i love and like a lot but it doesnt have a metro map running on servers and its also difficult to get two assistance medals with assault i cant get weapons that i love the most and']}
# ----------------------------------------
# Borderlands
#    Topic  Count                                    Name  \
# 0     -1      7               -1_is_was_the_borderlands
# 1      0     37                 0_borderlands_to_the_my
# 2      1     17  1_this_you_gearboxofficial_borderlands
# 3      2      6          2_pitchford_money_giving_randy
# 4      3      4                   3_mayhem_to_have_drop
#
#                                       Representation  \
# 0  [is, was, the, borderlands, to, it, graveward,...
# 1  [borderlands, to, the, my, and, is, it, on, fo...
# 2  [this, you, gearboxofficial, borderlands, and,...
# 3  [pitchford, money, giving, randy, their, do, b...
# 4  [mayhem, to, have, drop, probably, with, drops...
#
#                                  Representative_Docs
# 0  [bl3 using girl on fire for the end credits is...
# 1  [borderlands can we please fix the lag audio i...
# 2  [borderlands gearboxofficial duvalmagic prodig...
# 3  [borderlands how do i submit a complaint your ...
# 4  [i do wish borderlands would have given anothe...
# {-1: ['bl3 using girl on fire for the end credits is why im gonna quit borderlands forever', 'not saying the older games arent flawed   loot was terrible in older updates of bl2 terramorphous is a cheap and lazy raid boss compared to cramulaux in borderlands 1', 'i went to bed at 4am 5 hours before that at 9pm i was farming graveward it is now almost 4pm and i went to farm graveward again and on my first kill i tried to loot the vault but it was already looted borderlands ki11ersix what is wrong with my game it is the broken'], 0: ['borderlands can we please fix the lag audio issues and crashes on ps4 after the update it is very hard to play with 10 fps or less dont want this limited cartel to run out and not be able to play properly also menus fix the menu lag please', 'borderlands im unable to access any forums so i figured i would try here when im in boarderlands 3 if i turn to the right so that characters who are speaking are on my left side i cant hear them at all this is on ps4 is there some where you can point
# ----------------------------------------
# CallOfDutyBlackopsColdWar
#    Topic  Count                     Name  \
# 0     -1     19      -1_to_the_black_ops
# 1      0     41       0_the_war_cold_ops
# 2      1     31     1_this_shit_about_is
# 3      2      3         2_to_fuck_on_say
# 4      3      2  3_top_mastery_camo_date
#
#                                       Representation  \
# 0  [to, the, black, ops, for, cold, war, of, get,...
# 1  [the, war, cold, ops, it, black, is, and, this...
# 2  [this, shit, about, is, yall, oh, fix, please,...
# 3  [to, fuck, on, say, ps5, playstation, consoles...
# 4  [top, mastery, camo, date, bo1, worst, time, a...
#
#                                  Representative_Docs
# 0  [lets hope treyarch do something to remove the...
# 1  [black ops cold war is definitely a step down ...
# 2  [this shit is about to be so hard isnt it, oh ...
# 3  [exclusive to playstation oh fuck off pictwitt...
# 4  [bo1 is top 3 of all time,  worst mastery camo...
# {-1: ['lets hope treyarch do something to remove the racist and hateful language in black ops cold war since infinityward dont seem to give a shit', 'call of duty black ops cold war aka how to completely fuck up the shooting mechanics of the game', 'just got to 155 for the sixth time yay am so excited please treyarch add some kind of prestige mode for black ops cold war i dont want to go through another year of seasonal ranks its so dull'], 0: ['black ops cold war is definitely a step down from modern warfare theres no double time or leaning it feels dated the gunplay is slow the sounds are meh and weak in comparison', 'treyarch i preordered black ops cold war and it wont let me play the beta', 'cod black ops cold war sorry but the mechanics on the game are really shite it feels like im playing a really old game   '], 1: ['this shit is about to be so hard isnt it', 'oh scoob713 this is what u meant by that oh naw this is dog shit', 'im rt this again just to let yall know yall need to fix this shit'], 2: ['exclusive to playstation oh fuck off pictwittercom1nwftyvxex', 'say goodbye to your 825 gb on ps5 its all gonna be gone after this', 'yikes i have to pay more to play on both consoles fuck man'], 3: ['bo1 is top 3 of all time', ' worst mastery camo to date']}
# ----------------------------------------
# Cyberpunk2077
#    Topic  Count                     Name  \
# 0      0     26        0_my_this_to_shit
# 1      1     39  1_the_2077_cyberpunk_to
#
#                                       Representation  \
# 0  [my, this, to, shit, is, disappointment, news,...
# 1  [the, 2077, cyberpunk, to, is, it, not, and, b...
#
#                                  Representative_Docs
# 0  [ f to your wasted vacation days if youre unab...
# 1  [not sure if its an unpopular opinion but i do...
# {0: [' f to your wasted vacation days if youre unable to change them praise be if you can pictwittercomcjxtohd409', 'much to my disappointment this article i wrote back in june is going to stay relevant for an extra month', 'my disappointment is immeasurable and my day is ruined'], 1: ['not sure if its an unpopular opinion but i dont like this new thing about using models of real people for video game characters im not gonna be able to look at the cyberpunk 2077 protag and not say oh thats just keanu', 'yeaaah im not surprised from a ive heard of cdpr i had hoped the delay was for dev quality of life but in the industry the only cause for delay is when it needs to to be financially viable not humanitarian reasons', 'the year is 2077 now and we still not getting cyberpunk 2077']}
# ----------------------------------------
# Dota2
#    Topic  Count                           Name  \
# 0     -1      6   -1_my_high_sometimes_sadness
# 1      0     96             0_the_dota2_and_is
# 2      1     18           1_wtf_so_broken_shit
# 3      2      4  2_toxic_trashtalk_typical_sea
# 4      3      4             3_wasted_if_all_my
#
#                                       Representation  \
# 0  [my, high, sometimes, sadness, admit, youre, g...
# 1  [the, dota2, and, is, dota, to, of, this, game...
# 2  [wtf, so, broken, shit, jokes, ugly, added, he...
# 3  [toxic, trashtalk, typical, sea, racism, next,...
# 4  [wasted, if, all, my, fokin, moneeeeeeeyyyyy, ...
#
#                                  Representative_Docs
# 0  [i am stabbing and dota 2 smelly  casey, somet...
# 1  [at this point the dota community still exists...
# 2                                   [wtf , wtf, wtf]
# 3     [toxic carry, toxic, typical toxic sea server]
# 4  [1000 wasted, the way i can name all if not mo...
# {-1: ['i am stabbing and dota 2 smelly  casey', 'sometimes the high ground is bad redditgfzg3z', 'i admit nothing but my sadness that youre gone'], 0: ['at this point the dota community still exists out of pure stubbornness and the complaints are not due to the pandemic lets make it clear valve has abandoned this game andor let the community create their content for years now', 'wykrhm dota2 extremely upset with this years battlepass all the hype about arcanas and personas but theyre all at unachievable levels if you dont buy levels all the good features which helped us grind it out and level up are gone too sideshop is complete trash do something', 'most amount of fun you can get out of a moba is booting up dota 2 for the first time to see what all the fuss is about and then you shit your bones out when the valve guy turns around and stares into your soul you can uninstall the game after that its peaked'], 1: ['wtf ', 'wtf', 'wtf'], 2: ['toxic carry', 'toxic', 'typical toxic sea server'], 3: ['1000 wasted', 'the way i can name all if not most if these makes me think i have wasted my life', 'take all my fucking moneeeeeeeyyyyy']}
# ----------------------------------------
# FIFA
#    Topic  Count                      Name  \
# 0     -1     46       -1_fifa_the_this_is
# 1      0    123         0_fifa_the_and_is
# 2      1     19  1_damn_16h_praying_thank
# 3      2      5    2_workers_right_the_he
# 4      3      3    3_to_at_magically_find
#
#                                       Representation  \
# 0   [fifa, the, this, is, to, 21, of, so, and, that]
# 1    [fifa, the, and, is, to, my, in, for, of, game]
# 2  [damn, 16h, praying, thank, highest, huge, goa...
# 3  [workers, right, the, he, money, from, and, th...
# 4  [to, at, magically, find, listen, moaning, mus...
#
#                                  Representative_Docs
# 0  [go onto ut to see what the requirements were ...
# 1  [fifa wl is the most annoying thing in the wor...
# 2  [so damn sick, gets disrespectful reall quick ...
# 3  [gaming companies are terrible for getting ref...
# 4  [the bulk of our artists struggle, this is wha...
# {-1: ['go onto ut to see what the requirements were for the preseason stuff realised i was 1 win off of 12k so decided to get it first game played a sweaty nonce uninstalled mid game and get this the fifa community is the worst in existence pictwittercomp7kadpq53m', 'easportsfifa please explain to me how the fuck i lost this game is so unbalanced please dont tell me that fifa 21 is going to be this shit pictwittercomxx6yxxld6g', 'eafifamobile if i hadnt invested so much money in that shit i would have deleted the fuck and forgotten about it a long time ago the first and last fifa well done you have achieved that people are already looking for an alternative to your trash'], 0: ['fifa wl is the most annoying thing in the world im winning 21 in the 118th min and he scores a goal and then we go to pens and he blocks 3 in a row dude is fucking shitter too dominated the entire game he played 19 people in the back and i couldnt get a shot to go in', 'not interested
#                                       Representation  \
# 0  [company, is, because, to, this, another, skin...
# 1  [the, fortnite, fortnitegame, to, is, and, gam...
# 2  [by, tbh, stfu, offended, feels, should, feel,...
# 3  [quit, whole, twitlonger, thinking, rage, yes,...
# 4  [bullied, tweets, bullying, anyways, annoyed, ...
#
#                                  Representative_Docs
# 0  [fortnitegame id rather jerk off with hot sauc...
# 1  [fortnite must have forgot about console when ...
# 2  [stfu lol, that sucks tbh, i dont know if i sh...
# 3  [im thinking to quit fortnite, going to make a...
# 4  [i am being bullied into submission, fortnite ...
# {-1: ['fortnitegame id rather jerk off with hot sauce at this point because i would feel more excitement from that than playing this game', 'literally every company ever i think i just need to start supporting every scummy company because theres no good side to a company k', 'this is literally stupid a company thats worths billions being petty because another company wants their share from your game being on their app store '], 0: ['fortnite must have forgot about console when the new update came out i have been losing lots of 1v1 due to the fact of delay and the new console editing system like this post if you think fortnite forgot about console console players', 'bro fuck the bots in fortnite this game is so shit', 'fortnitegame you actually ruined the game for me and so many else with the aim assist nerf and we dont even have scope sens you have to fix it or you will lose so many players'], 1: ['stfu lol', 'that sucks tbh', 'i dont know if i should feel offended by this'], 2: ['im thinking to quit fortnite', 'going to make a twitlonger explaining why i might quit fortnite as a whole ', 'i quit'], 3: ['i am being bullied into submission', 'fortnite is bullying me arent they i need him pictwittercom3q3yxuxkfy', 'anyways ignore my fortnite tweets im annoyed ']}
# ----------------------------------------
# Google
#    Topic  Count                            Name  \
# 0     -1     24             -1_google_the_to_of
# 1      0     59             0_google_to_and_the
# 2      1      8                1_we_all_you_own
# 3      2      6  2_this_weareoneexo_please_that
# 4      3      2    3_battery_greatest_pro_pixel
#
#                                       Representation  \
# 0   [google, the, to, of, and, you, my, id, for, is]
# 1   [google, to, and, the, you, my, not, is, it, me]
# 2  [we, all, you, own, your, twitter, the, go, li...
# 3  [this, weareoneexo, please, that, hi, us, noti...
# 4  [battery, greatest, pro, pixel, max, iphone, s...
#
#                                  Representative_Docs
# 0  [yandexby google told a big lie to the whole w...
# 1  [my google hangouts is not working my laptop w...
# 2  [really starting to like, remember that tune y...
# 3  [please hear us out  hi google  we noticed tha...
# 4  [useless in sa, iphone 11 pro max 3969mah batt...
# {-1: ['yandexby google told a big lie to the whole world you need to read this duzdunyacomtr and report please do a headline the world need to know this', 'if you kill someone to make a point   of how google   and vice and the ny times   play to the life science companies   theyll use a horrible photo of you ', 'ive been looking online using the google search engine for videos of the republican convention google not very helpful turned to duckduckgo and got immediate helpful links almost like google doesnt want you to find these videos'], 0: ['my google hangouts is not working my laptop wont restart or work and i had work to finish before this next meeting at half 4 i think its time a call it a day', 'googleads google stop making people who call support go through 3 rounds of identification i know you figured out that your reps receive less calls if you bother your customers for longer but this is just a time wasting maneuver and is not appreciated', 'i cannot believe google absolutely killed googledrive by not allowing to add a folder to my drive so it automatically syncs on my computer if they dont backtrack before sept 30 it will be time to make the final move too dropbox '], 1: ['really starting to like', 'remember that tune you can go your own way my version is getting censored every day hey liar fact checkers google
# ----------------------------------------
# Hearthstone
#    Topic  Count                      Name  \
# 0     -1     11    -1_and_broken_the_cant
# 1      0     64   0_the_to_hearthstone_it
# 2      1      6   1_shit_bring_shame_king
# 3      2      5  2_hunter_demon_this_6699
# 4      3      2   3_the_game_this_include
#
#                                       Representation  \
# 0  [and, broken, the, cant, get, an, playhearthst...
# 1  [the, to, hearthstone, it, and, playhearthston...
# 2  [shit, bring, shame, king, greedy, dragons, ho...
# 3  [hunter, demon, this, 6699, responsible, hold,...
# 4  [the, game, this, include, purposely, would, p...
#
#                                  Representative_Docs
# 0  [hey playhearthstone wtaf i cant get an oppone...
# 1  [blizzardcs ive been trying to get into playhe...
# 2  [too greedy, king shit , holy shit arena sucks...
# 3  [fucking imba this demon hunter, dang arena wh...
# 4  [i think the one thing i hate about this game ...
# {-1: ['hey playhearthstone wtaf i cant get an opponent in ten minutes on arena im certainly not going to sit here for an hour waiting whats up with your matchmaking system pictwittercompklu0kflsi', 'playhearthstone the servers are not working and they keep kicking me and my friends out allday long not the mention the matches i could play all standard and ranked matches around 810 in a row where against priests and their broken reborn deck it cant just be coincidence', 'to the guy that keeps tryna hack my battlenet account you can fucking have it all you get is overshit level 20 wow classic orc and half finished basic set for hearthstone'], 0: ['blizzardcs ive been trying to get into playhearthstone on ios and it keeps taking me to the app store to update even though ive installed the latest updateboth on ipad and iphone can you help', 'blizzardcs whats going on with hearthstone for ipad i deleted the app then redownloaded and it is still saying to restart the app any idea on when the patch will be live for ios', 'playhearthstone on the mobile version i only get to see a message saying i need to update the game will not update and will not open it but when i go into the play store i only get a button to open the app is there any fix for this coming anytime soon'], 1: ['too greedy', 'king shit ', 'holy shit arena sucks now bring back all the dragons'], 2: ['fucking imba this demon hunter', 'dang arena why you have to do demon hunter so dirty ', 'dear hearthstone community  stop playing demon hunter please its cancer'], 3: ['i think the one thing i hate about this game are the people who purposely wait until the rope counts down to do their turn', 'i wish playhearthstone had told at the beginning of this year that they were planning a game mode that would include wild cards ive disenchanted so many to keep up with ladder such a bummer man']}
# ----------------------------------------
# HomeDepot
#    Topic  Count                      Name  \
# 0     -1     20       -1_home_to_depot_in
# 1      0     98       0_to_home_depot_the
# 2      1     23   1_you_were_to_screaming
# 3      2      7      2_the_will_to_longer
# 4      3      2  3_and_ceiling_didnt_your
#
#                                       Representation  \
# 0  [home, to, depot, in, of, have, people, the, w...
# 1  [to, home, depot, the, and, homedepot, for, in...
# 2  [you, were, to, screaming, idiot, im, this, ar...
# 3  [the, will, to, longer, needs, are, of, boycot...
# 4  [and, ceiling, didnt, your, httpstcolfmvg6dwvh...
#
#                                  Representative_Docs
# 0  [falling asleep and thought of a brilliant ide...
# 1  [homedepot when will i hear back about the los...
# 2  [this is a hard one because theyre so convenie...
# {-1: ['im toxic af on league of legends idk question mark pinging people is funny to me ', 'why do games always have to make the ugliest most annoying male characters and just add the playboy trait to them and all of you fall for it stop making me look at mirage apexlegends and sett leagueoflegends fuck its so annoying', 'is riot doing anything about the amount of accounts being sold in league of legends right now  its making climbing through gold as an actual gold players nearly impossible which obviously creates a toxic environment stop making new characters and fix your game httpstcotpft56b5di'], 0: ['cant stress it enough that seraphine is the worst fucking thing league of legends implemented not only lore and gamplay wise but also the marketing i might actually quit league because of it', 'fucking hate league of legends', 'league of legends to me is the one toxic ex i keep going back to eventho i know its a waste of time and is killing my productivity'], 1: ['just faced the blindness status in', 'a rubber is the real life qss', 'tbh looking at all these talented dudes and how low their sub count is makes me really uncomfortable'], 2: ['holy shit what world are we in', 'the world if league of legends didnt exist pictwittercomcnsgmr4uro', 'id whale the shit out of this if kojimas involved yall'], 3: ['starting to hate this game', 'is the fact that my crush plays that shit enough of a reason to stop liking him', 'btw that wasnt serious i hate this game']}
# ----------------------------------------
# MaddenNFL
#    Topic  Count                             Name  \
# 0     -1     48        -1_the_eamaddennfl_to_and
# 1      0    170        0_eamaddennfl_the_game_to
# 2      1     43                  1_in_is_the_and
# 3      2     19                2_lmao_this_it_is
# 4      3      5  3_disrespect_keenan_facts_4real
#
# ...
# ----------------------------------------
# TomClancysRainbowSix
#    Topic  Count                                           Name  \
# 0     -1     45                     -1_rainbow6game_the_and_to
# 1      0    103                    0_the_rainbow6game_and_game
# 2      1     16                1_ranked_match_and_rainbow6game
# 3      2     16  2_ubisoft_rainbow6game_ubisoftsupport_cheater
# 4      3      7                 3_rn_feelings_crap_conflicting
#
#                                       Representation  \
# 0  [rainbow6game, the, and, to, game, it, you, my...
# 1  [the, rainbow6game, and, game, to, in, is, on,...
# 2  [ranked, match, and, rainbow6game, was, on, th...
# 3  [ubisoft, rainbow6game, ubisoftsupport, cheate...
# 4  [rn, feelings, crap, conflicting, well, joke, ...
#
#                                  Representative_Docs
# 0  [rainbow6game ubisoftsupport everyone in our r...
# 1  [rainbow6game ubisoftsupport you seriously nee...
# 2  [rainbow6game  we qued for ranked as 5 with my...
# 3  [help ubisoft ubisoftsupport rainbow6game  on ...
# 4  [well crap, i have very conflicting feelings r...
# {-1: ['rainbow6game ubisoftsupport everyone in our ranked game lagged out because of the servers this is the second time today ive lost a ranked match to this and i now have a 60 minuate ban can i please get my mmr back or get back or something this is bs please help', 'rainbow6game trying to play ranked on pc is difficult when you get booted from the game try to rejoin and it tells you over and over that the server is unavailable esports ready my ass you guys cant help me to figure out why i cannot rejoin a ranked game', 'rainbow6game is there any way to stop the players from using keyboard and mouse on console it is ruining the fun from the game for my friends and i may you please fix this issue'], 0: ['rainbow6game ubisoftsupport you seriously need to fix whatever is going on it takes a good 30 mins just to get 5 people in the same squad and then during the match at 44 my teammate loses connection to the siege servers and we lost due to it being 5v4', 'its time you fix your servers ubisoft me and my friend were playing the new event mode everyone got kicked from the server resulting in a 30min abandon sanction and renown penalty when are you going to do something about this rainbow6game pictwittercomhn1hs9xwcc', 'rainbow6game so my internet dis